# %%
import optuna
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.special import expit
from lightgbm import LGBMRegressor
from sklearn.metrics import root_mean_squared_error
from sklearn.model_selection import train_test_split, cross_validate
from perpetual import PerpetualBooster

# %%
pd.set_option('display.max_rows', 1000)

# %%
# !python --version
# Out:
# Python 3.9.20

# %%
from importlib.metadata import version

print(f"numpy: {version('numpy')}")
print(f"optuna: {version('optuna')}")
print(f"lightgbm: {version('lightgbm')}")
print(f"scikit-learn: {version('scikit-learn')}")
print(f"perpetual: {version('perpetual')}")
# Out:
# numpy: 1.26.4
# optuna: 4.0.0
# lightgbm: 4.5.0
# scikit-learn: 1.3.2
# perpetual: 0.4.9

# %%
df = sns.load_dataset("diamonds")

# %%
df.dtypes
# Out:
# carat       float64
# cut        category
# color      category
# clarity    category
# depth       float64
# table       float64
# price         int64
# x           float64
# y           float64
# z           float64
# dtype: object

# %%
X = df.drop(columns=["price", "y"])
y = df["price"]

# %%
X.shape
# Out:
# (53940, 8)

# %%
X.dtypes
# Out:
# carat       float64
# cut        category
# color      category
# clarity    category
# depth       float64
# table       float64
# x           float64
# z           float64
# dtype: object

# %%
X.nunique()
# Out:
# carat      273
# cut          5
# color        7
# clarity      8
# depth      184
# table      127
# x          554
# z          375
# dtype: int64

# %%
X.head()
# Out:
#    carat      cut color clarity  depth  table     x     z
# 0   0.23    Ideal     E     SI2   61.5   55.0  3.95  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0  3.89  2.31
# 2   0.23     Good     E     VS1   56.9   65.0  4.05  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0  4.20  2.63
# 4   0.31     Good     J     SI2   63.3   58.0  4.34  2.75

# %%
cols = ['cut', 'color', 'clarity']
X[cols] = X[cols].astype('category')
X.head()
# Out:
#    carat      cut color clarity  depth  table     x     z
# 0   0.23    Ideal     E     SI2   61.5   55.0  3.95  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0  3.89  2.31
# 2   0.23     Good     E     VS1   56.9   65.0  4.05  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0  4.20  2.63
# 4   0.31     Good     J     SI2   63.3   58.0  4.34  2.75

# %%
seed = 42
n_estimators = 100
n_trials = 1

# %%
scoring = "neg_root_mean_squared_error"
metric_function = root_mean_squared_error
metric_name = "rmse"
LGBMBooster = LGBMRegressor
objective = "SquaredLoss"

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

print(f"X_train.shape: {X_train.shape}")
print(f"X_test.shape: {X_test.shape}")
# Out:
# X_train.shape: (43152, 8)
# X_test.shape: (10788, 8)

# %%
X_train.head()
# Out:
#        carat        cut color clarity  depth  table     x     z
# 26546   2.01       Good     F     SI2   58.1   64.0  8.23  4.77
# 9159    1.01  Very Good     E     SI2   60.0   60.0  6.57  3.92
# 14131   1.10    Premium     H     VS2   62.5   58.0  6.59  4.10
# 15757   1.50       Good     E     SI2   61.5   65.0  7.21  4.42
# 24632   1.52  Very Good     G     VS1   62.1   57.0  7.27  4.53

# %%
best_cv_results = None
cv_results = None

def save_best_cv_results(study, trial):
    global best_cv_results
    if study.best_trial.number == trial.number:
        best_cv_results = cv_results

# %%
def objective_function(trial):
    global cv_results
    params = {
        'seed': seed,
        'verbosity': -1,
        'n_estimators': n_estimators,
        'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.5, log=True),
        'min_split_gain': trial.suggest_float('min_split_gain', 1e-6, 1.0, log=True),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-6, 1.0, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-6, 1.0, log=True),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.2, 1.0),
        'subsample': trial.suggest_float('subsample', 0.2, 1.0),
        'subsample_freq': trial.suggest_int('subsample_freq', 1, 10),
        'max_depth': trial.suggest_int('max_depth', 3, 33),
        'num_leaves': trial.suggest_int('num_leaves', 2, 1024),
        'min_child_samples': trial.suggest_int('min_child_samples', 1, 100),
    }
    model = LGBMBooster(**params)
    cv_results = cross_validate(model, X_train, y_train, cv=5, scoring=scoring, return_train_score=True, return_estimator=True)
    return -1 * np.mean(cv_results['test_score'])

# %%
sampler = optuna.samplers.TPESampler(seed=seed)
study = optuna.create_study(direction='minimize', sampler=sampler)
# Out:
# [I 2024-10-08 18:52:38,249] A new study created in memory with name: no-name-e0817de5-0a6e-479e-b19f-175b92e23e3c

# %%
# %%time
study.optimize(objective_function, n_trials=n_trials, callbacks=[save_best_cv_results])
# Out:
# [I 2024-10-08 18:52:49,076] Trial 0 finished with value: 2000.9810667524173 and parameters: {'learning_rate': 0.010253509690168494, 'min_split_gain': 0.5061576888752307, 'reg_alpha': 0.02465832945854911, 'reg_lambda': 0.003907967156822882, 'colsample_bytree': 0.3248149123539492, 'subsample': 0.32479561626896214, 'subsample_freq': 1, 'max_depth': 29, 'num_leaves': 616, 'min_child_samples': 71}. Best is trial 0 with value: 2000.9810667524173.
# CPU times: total: 13.6 s
# Wall time: 10.8 s

# %%
print(f"Number of finished trials: {len(study.trials)}")
print("Best trial:")
print(f"  Number: {study.best_trial.number}")
print(f"  Value: {study.best_trial.value}")
print("  Params: ")
for key, value in study.best_trial.params.items():
    print(f"    {key}: {value}")
# Out:
# Number of finished trials: 1
# Best trial:
#   Number: 0
#   Value: 2000.9810667524173
#   Params:
#     learning_rate: 0.010253509690168494
#     min_split_gain: 0.5061576888752307
#     reg_alpha: 0.02465832945854911
#     reg_lambda: 0.003907967156822882
#     colsample_bytree: 0.3248149123539492
#     subsample: 0.32479561626896214
#     subsample_freq: 1
#     max_depth: 29
#     num_leaves: 616
#     min_child_samples: 71

# %%
print(f"CV train scores: {-1 * best_cv_results['train_score']}")
print(f"CV train scores average : {round(np.mean(-1 * best_cv_results['train_score']), 6)}")
print(f"CV test scores: {-1 * best_cv_results['test_score']}")
print(f"CV test scores average : {round(np.mean(-1 * best_cv_results['test_score']), 6)}")
# Out:
# CV train scores: [2001.35132941 1985.85304801 1991.68952646 1994.88802646 1995.95054575]
# CV train scores average : 1993.946495
# CV test scores: [1946.69602094 2027.02009529 2008.70797558 2009.34186745 2013.1393745 ]
# CV test scores average : 2000.981067

# %%
models = best_cv_results["estimator"]

# %%
for i, model in enumerate(models):
    y_pred = model.predict_proba(X_train) if metric_name == "log_loss" else model.predict(X_train)
    print(f"Model {i}, train {metric_name}: {round(metric_function(y_train, y_pred), 6)}")
# Out:
# Model 0, train rmse: 1990.539574
# Model 1, train rmse: 1994.155022
# Model 2, train rmse: 1995.104672
# Model 3, train rmse: 1997.787026
# Model 4, train rmse: 1999.399974

# %%
for i, model in enumerate(models):
    y_pred = model.predict_proba(X_test) if metric_name == "log_loss" else model.predict(X_test)
    print(f"Model {i}, test {metric_name}: {round(metric_function(y_test, y_pred), 6)}")
# Out:
# Model 0, test rmse: 1982.119395
# Model 1, test rmse: 1984.355572
# Model 2, test rmse: 1985.41774
# Model 3, test rmse: 1988.498437
# Model 4, test rmse: 1989.999609

# %%
if metric_name == "log_loss":
    y_pred = np.mean([model.predict_proba(X_train) for model in models], axis=0)
else:
    y_pred = np.mean([model.predict(X_train) for model in models], axis=0)
print(f"Train {metric_name}: {round(metric_function(y_train, y_pred), 6)}")
# Out:
# Train rmse: 1995.166118

# %%
if metric_name == "log_loss":
    y_pred = np.mean([model.predict_proba(X_test) for model in models], axis=0)
else:
    y_pred = np.mean([model.predict(X_test) for model in models], axis=0)
print(f"Test {metric_name}: {round(metric_function(y_test, y_pred), 6)}")
# Out:
# Test rmse: 1985.84433

# %%
model = PerpetualBooster(objective=objective)
model.fit(X_train, y_train, budget=1.0)
# Out:
# Categorical features: [1, 2, 3]
# Mapping of categories: {'cut': ['nan', 'Fair', 'Good', 'Ideal', 'Premium', 'Very Good'], 'color': ['nan', 'D', 'E', 'F', 'G', 'H', 'I', 'J'], 'clarity': ['nan', 'I1', 'IF', 'SI1', 'SI2', 'VS1', 'VS2', 'VVS1', 'VVS2']}
# ---------------------------------------------------------------------------
# PanicException                            Traceback (most recent call last)
# Cell In[58], line 2
#       1 model = PerpetualBooster(objective=objective)
# ----> 2 model.fit(X_train, y_train, budget=1.0)
#
# File c:\ProgramData\miniconda3\envs\py310\lib\site-packages\perpetual\booster.py:237, in PerpetualBooster.fit(self, X, y, sample_weight, budget, alpha, reset, categorical_features)
#     232 self._set_metadata_attributes(
#     233     "feature_importance_method", self.feature_importance_method
#     234 )
#     235 self._set_metadata_attributes("classes_", self.classes_)
# --> 237 self.booster.fit(
#     238     flat_data=flat_data,
#     239     rows=rows,
#     240     cols=cols,
#     241     y=y_,
#     242     budget=budget,
#     243     sample_weight=sample_weight_,  # type: ignore
#     244     alpha=alpha,
#     245     reset=reset,
#     246     categorical_features=categorical_features_,  # type: ignore
#     247 )
#     249 return self
#
# PanicException: called `Option::unwrap()` on a `None` value

# %%
if metric_name == "log_loss":
    y_pred = expit(model.predict(X_test))
else:
    y_pred = np.round(expit(model.predict(X_test)))
print(f"Test {metric_name}: {round(metric_function(y_test, y_pred), 6)}")

# %%
df_trees = model.trees_to_dataframe()

# %%
df_trees.head(10)

# %%
models[4].booster_.trees_to_dataframe().head(100)
# Out:
#     tree_index  node_depth node_index left_child right_child parent_index  \
# 0            0           1       0-S0       0-S2        0-S1         None
# 1            0           2       0-S2       0-S6        0-S5         0-S0
# 2            0           3       0-S6      0-S19       0-S25         0-S2
# 3            0           4      0-S19      0-S36       0-S49         0-S6
# 4            0           5      0-S36      0-S71       0-S56        0-S19
# 65           0          12      0-L89       None        None        0-S98
# 66           0          12      0-L99       None        None        0-S98
# 67           0          11      0-L90       None        None        0-S89
# 68           0           9      0-L71       None        None        0-S70
# 69           0           8     0-S104      0-L70      0-L105        0-S69
# 70           0           9      0-L70       None        None       0-S104
# 71           0           9     0-L105       None        None       0-S104
# 72           0           5      0-S53      0-L26       0-S61        0-S25
# 73           0           6      0-L26       None        None        0-S53
# 74           0           6      0-S61      0-S80       0-L62        0-S53
# 75           0           7      0-S80      0-S81       0-L81        0-S61
# 76           0           8      0-S81      0-S84       0-S97        0-S80
# 77           0           9      0-S84      0-L54       0-L85        0-S81
# 78           0          10      0-L54       None        None        0-S84
# 79           0          10      0-L85       None        None        0-S84
# 80           0           9      0-S97      0-L82       0-L98        0-S81
# 81           0          10      0-L82       None        None        0-S97
# 82           0          10      0-L98       None        None        0-S97
# 83           0           8      0-L81       None        None        0-S80
# 84           0           7      0-L62       None        None        0-S61
# 85           0           3       0-S5      0-S17       0-S14         0-S2
# 86           0           4      0-S17      0-S39       0-S20         0-S5
# 87           0           5      0-S39      0-S68       0-S77        0-S17
# 88           0           6      0-S68       0-L3       0-L69        0-S39
# 89           0           7       0-L3       None        None        0-S68
# 90           0           7      0-L69       None        None        0-S68
# 91           0           6      0-S77      0-L40       0-S83        0-S39
# 92           0           7      0-L40       None        None        0-S77
# 93           0           7      0-S83      0-L78       0-L84        0-S77
# 94           0           8      0-L78       None        None        0-S83
# 95           0           8      0-L84       None        None        0-S83
# 96           0           5      0-S20      0-S28       0-S45        0-S17
# 97           0           6      0-S28      0-S59       0-S66        0-S20
# 98           0           7      0-S59      0-S73       0-L60        0-S28
# 99           0           8      0-S73      0-L18       0-L74        0-S59
#
#    split_feature    split_gain threshold decision_type missing_direction  \
# 0              x  1.056110e+11     6.315            <=              left
# 1              x  6.684040e+09     5.515            <=              left
# 2              x  8.923030e+08     4.985            <=              left
# 3              x  5.383010e+07     4.625            <=              left
# 4              x  1.186770e+07     4.275            <=              left
# 5              x  9.028280e+05     4.145            <=              left
# 6              x  3.886520e+04     3.995            <=              left
# 7           None           NaN      None          None              None
# 8           None           NaN      None          None              None
# 9              x  3.938380e+04     4.245            <=              left
# 10          None           NaN      None          None              None
# 11          None           NaN      None          None              None
# 12             x  2.694090e+06     4.375            <=              left
# 13             z  7.815950e+05     2.715            <=              left
# 14             x  4.900410e+05     4.315            <=              left
# 15          None           NaN      None          None              None
# 16             z  1.984320e+05     2.685            <=              left
# 17             z  8.582690e+04     2.655            <=              left
# 18          None           NaN      None          None              None
# 19          None           NaN      None          None              None
# 20          None           NaN      None          None              None
# 21          None           NaN      None          None              None
# 22             z  2.996220e+05     2.665            <=              left
# 23          None           NaN      None          None              None
# 24             x  1.446020e+05     4.405            <=              left
# 25             z  1.228920e+05     2.725            <=              left
# 26          None           NaN      None          None              None
# 27          None           NaN      None          None              None
# 28             x  1.752620e+04     4.585            <=              left
# 29             x  2.041830e+04     4.525            <=              left
# 30             x  6.041350e+04     4.485            <=              left
# 31          None           NaN      None          None              None
# 32          None           NaN      None          None              None
# 33          None           NaN      None          None              None
# 34          None           NaN      None          None              None
# 35             x  4.552100e+06     4.755            <=              left
# 36             z  6.754590e+05     2.965            <=              left
# 37             x  2.335240e+05     4.685            <=              left
# 38          None           NaN      None          None              None
# 39             z  9.158390e+04     2.905            <=              left
# 40          None           NaN      None          None              None
# 41             x  8.771970e+04     4.725            <=              left
# 42          None           NaN      None          None              None
# 43          None           NaN      None          None              None
# 44          None           NaN      None          None              None
# 45             x  1.810620e+06     4.905            <=              left
# 46             z  3.429830e+05     2.905            <=              left
# 47          None           NaN      None          None              None
# 48             z  2.199300e+05     3.005            <=              left
# 49             x  1.559430e+05     4.835            <=              left
# 50          None           NaN      None          None              None
# 51          None           NaN      None          None              None
# 52          None           NaN      None          None              None
# 53          None           NaN      None          None              None
# 54             x  3.033960e+07     5.245            <=              left
# 55             x  5.505800e+06     5.075            <=              left
# 56          None           NaN      None          None              None
# 57             z  1.923150e+06     3.125            <=              left
# 58          None           NaN      None          None              None
# 59             x  1.287340e+06     5.205            <=              left
# 60             z  1.051500e+06     3.225            <=              left
# 61             x  1.990290e+05     5.125            <=              left
# 62          None           NaN      None          None              None
# 63             z  3.288630e+05     3.195            <=              left
# 64             z  4.492510e+04     3.165            <=              left
# 65          None           NaN      None          None              None
# 66          None           NaN      None          None              None
# 67          None           NaN      None          None              None
# 68          None           NaN      None          None              None
# 69             z  1.635000e+04     3.215            <=              left
# 70          None           NaN      None          None              None
# 71          None           NaN      None          None              None
# 72             z  4.039480e+06     3.195            <=              left
# 73          None           NaN      None          None              None
# 74             z  1.885560e+06     3.355            <=              left
# 75             x  3.188340e+05     5.395            <=              left
# 76             x  5.309730e+05     5.315            <=              left
# 77             x  2.700600e+05     5.285            <=              left
# 78          None           NaN      None          None              None
# 79          None           NaN      None          None              None
# 80             z  5.284410e+04     3.295            <=              left
# 81          None           NaN      None          None              None
# 82          None           NaN      None          None              None
# 83          None           NaN      None          None              None
# 84          None           NaN      None          None              None
# 85             z  9.426800e+08     3.755            <=              left
# 86             x  6.377580e+07     5.705            <=              left
# 87             x  9.021440e+06     5.645            <=              left
# 88             x  1.631960e+06     5.595            <=              left
# 89          None           NaN      None          None              None
# 90          None           NaN      None          None              None
# 91             z  4.910630e+05     3.525            <=              left
# 92          None           NaN      None          None              None
# 93             z  2.864290e+05     3.555            <=              left
# 94          None           NaN      None          None              None
# 95          None           NaN      None          None              None
# 96             z  3.994330e+07     3.665            <=              left
# 97             z  1.789730e+07     3.525            <=              left
# 98             z  2.176260e+06     3.495            <=              left
# 99             x  7.317360e+05     5.795            <=              left
#
#    missing_type        value  weight  count
# 0          None  3933.270000       0  11214
# 1          None  3910.190000    7332   7332
# 2          None  3903.840000    5158   5158
# 3          None  3901.080000    3641   3641
# 4          None  3900.210000    2446   2446
# 5          None  3898.740000     469    469
# 6          None  3898.260000     221    221
